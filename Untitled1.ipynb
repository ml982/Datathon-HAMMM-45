# %%
import pandas as pd

# %%
df = pd.read_csv('RoughSleepers.csv')

# %%
df = df.set_index(list(df)[0])

# %%
df
# Out:
#                            GSS Code  2019/20  2020/21  2021/22  2022/23  \
# Area
# Greater London Authority  E12000007    10726    11018     8329    10053
# Barking & Dagenham        E09000002       85      161      131      139
# Barnet                    E09000003      178      282      173      166
# Bexley                    E09000004       42       88       93       92
# Brent                     E09000005      320      374      283      373
# Bromley                   E09000006       67       54       57       92
# Camden                    E09000007      639      630      666      719
# City of London            E09000001      434      350      372      482
# Croydon                   E09000008      306      322      271      373
# Ealing                    E09000009      493      624      448      563
# Enfield                   E09000010      206      326      183      219
# Greenwich                 E09000011      133      213      135      196
# ...
