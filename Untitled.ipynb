# %%
import pandas as pd

# %%
df = pd.read_csv('Householdhomelessdata.csv')

# %%
df
# Out:
#                                         Unnamed: 0  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 330                                            NaN
# 331  DLUHC H-CLIC Homelessness returns (quarterly)
# 332    email: homelessnessstats@levellingup.gov.uk
# 333                     Latest update: August 2024
# 334                       Next update: Autumn 2024
#
#                                  Unnamed: 1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3    Number of households\n in area5 (000s)
# 4                                       NaN
# ..                                      ...
# ...

# %%
df = df.head(316)

# %%
df = df.dropna(how='all')

# %%
df.columns = df.iloc[0]
df = df[1:]

# %%
df = df.rename(columns={ df.columns[0]: "Location" })

# %%
df.set_index(list(df)[0])
# Out:
# 3               Number of households\n in area5 (000s)  \
# Location
# ENGLAND                                         24,140
# London                                           3,660
# Rest of England                                 20,480
# North East                                       1,200
# North West                                       3,230
# ...                                                ...
# Worthing                                            52
# Wychavon                                            59
# Wyre                                                52
# Wyre Forest                                         47
# York                                                88
#
# 3               Households assessed as threatened with homelessness\nper (000s)  \
# Location
# ENGLAND                                                      1.59
# London                                                       2.03
# Rest of England                                              1.51
# ...

# %%
df.to_csv('Household.csv')

# %%
df
